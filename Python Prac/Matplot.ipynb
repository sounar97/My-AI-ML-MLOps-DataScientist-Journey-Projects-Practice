# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([0,6])
ypoints=np.array([0,250])

plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([1,3])
ypoints=np.array([8,10])

plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# Draw a line i a diagra, from position (1,3) to (2,8) then to (6,1)

# %%
ypoints=np.array([3,8,1,10,5,7])

plt.plot(ypoints,marker='o',ms=20,mfc='r')
plt.show()

# %% [markdown]
# Create data frame for month and totoal profit,Read Total profit of all months and show it using a line plot total profit data provided for each month
#
# Genereated lin eplot must include the following properties-
